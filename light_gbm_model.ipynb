# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold

# %%
# %%time
import warnings
warnings.filterwarnings('ignore')
train_df = pd.read_csv('train.csv.zip')
test_df = pd.read_csv('test.csv.zip')
features = [c for c in train_df.columns if c not in ['ID_code', 'target']]
target = train_df['target']
param = {
    'bagging_freq': 5,          
    'bagging_fraction': 0.331,   'boost_from_average':'false',   
    'boost': 'gbdt',             'feature_fraction': 0.0405,     'learning_rate': 0.0083,
    'max_depth': -1,             'metric':'auc',                'min_data_in_leaf': 80,     'min_sum_hessian_in_leaf': 10.0,
    'num_leaves': 13,            'num_threads': 4,              'tree_learner': 'serial',   'objective': 'binary',      'verbosity': 1
}
folds = StratifiedKFold(n_splits=15, shuffle=False, random_state=2319)
oof = np.zeros(len(train_df))
predictions = np.zeros(len(test_df))
for fold_, (trn_idx, val_idx) in enumerate(folds.split(train_df.values, target.values)):
    print("Fold {}".format(fold_))
    trn_data = lgb.Dataset(train_df.iloc[trn_idx][features], label=target.iloc[trn_idx])
    val_data = lgb.Dataset(train_df.iloc[val_idx][features], label=target.iloc[val_idx])
    clf = lgb.train(param, trn_data, 1000000, valid_sets = [trn_data, val_data], verbose_eval=5000, early_stopping_rounds = 4000)
    oof[val_idx] = clf.predict(train_df.iloc[val_idx][features], num_iteration=clf.best_iteration)
    predictions += clf.predict(test_df[features], num_iteration=clf.best_iteration) / folds.n_splits
print("CV score: {:<8.5f}".format(roc_auc_score(target, oof)))
sub = pd.DataFrame({"ID_code": test_df.ID_code.values})
sub["target"] = predictions
sub.to_csv("submission.csv", index=False)
# Out:
# Fold 0
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.924552	valid_1's auc: 0.898921
# [10000]	training's auc: 0.939897	valid_1's auc: 0.902141
# [15000]	training's auc: 0.952567	valid_1's auc: 0.902135
# Early stopping, best iteration is:
# [12135]	training's auc: 0.945611	valid_1's auc: 0.902544
# Fold 1
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.925025	valid_1's auc: 0.891776
# [10000]	training's auc: 0.940394	valid_1's auc: 0.894133
# [15000]	training's auc: 0.952955	valid_1's auc: 0.894247
# Early stopping, best iteration is:
# [13393]	training's auc: 0.949155	valid_1's auc: 0.894569
# Fold 2
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.924326	valid_1's auc: 0.901471
# [10000]	training's auc: 0.939786	valid_1's auc: 0.903285
# [15000]	training's auc: 0.952419	valid_1's auc: 0.9033
# Early stopping, best iteration is:
# [11670]	training's auc: 0.944299	valid_1's auc: 0.903758
# Fold 3
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.925161	valid_1's auc: 0.886608
# [10000]	training's auc: 0.940476	valid_1's auc: 0.889182
# [15000]	training's auc: 0.953063	valid_1's auc: 0.889419
# Early stopping, best iteration is:
# [12174]	training's auc: 0.94624	valid_1's auc: 0.889711
# Fold 4
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.923982	valid_1's auc: 0.90726
# [10000]	training's auc: 0.939498	valid_1's auc: 0.90912
# Early stopping, best iteration is:
# [10149]	training's auc: 0.939932	valid_1's auc: 0.909132
# [5000]	training's auc: 0.925087	valid_1's auc: 0.891309
# [10000]	training's auc: 0.940357	valid_1's auc: 0.892542
# Early stopping, best iteration is:
# [8432]	training's auc: 0.936016	valid_1's auc: 0.892697
# Fold 6
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.924482	valid_1's auc: 0.899191
# [10000]	training's auc: 0.940009	valid_1's auc: 0.900714
# Early stopping, best iteration is:
# [8846]	training's auc: 0.93676	valid_1's auc: 0.900902
# Fold 7
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.924682	valid_1's auc: 0.89908
# [10000]	training's auc: 0.940089	valid_1's auc: 0.901228
# Early stopping, best iteration is:
# [10016]	training's auc: 0.940139	valid_1's auc: 0.901242
# Fold 8
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.924245	valid_1's auc: 0.903141
# [10000]	training's auc: 0.93968	valid_1's auc: 0.904204
# [15000]	training's auc: 0.952297	valid_1's auc: 0.904177
# Early stopping, best iteration is:
# [12119]	training's auc: 0.945315	valid_1's auc: 0.904681
# Fold 9
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.924345	valid_1's auc: 0.900922
# [10000]	training's auc: 0.939718	valid_1's auc: 0.90199
# Early stopping, best iteration is:
# [9756]	training's auc: 0.939067	valid_1's auc: 0.902168
# Fold 10
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.924701	valid_1's auc: 0.895683
# [10000]	training's auc: 0.940026	valid_1's auc: 0.89782
# [15000]	training's auc: 0.952487	valid_1's auc: 0.897764
# Early stopping, best iteration is:
# [13119]	training's auc: 0.948058	valid_1's auc: 0.898076
# Fold 11
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.924345	valid_1's auc: 0.901275
# [10000]	training's auc: 0.939821	valid_1's auc: 0.90322
# Early stopping, best iteration is:
# [8181]	training's auc: 0.934783	valid_1's auc: 0.90331
# Fold 12
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.92441	valid_1's auc: 0.901918
# [10000]	training's auc: 0.939893	valid_1's auc: 0.903297
# Early stopping, best iteration is:
# [9191]	training's auc: 0.937661	valid_1's auc: 0.903444
# Fold 13
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.923896	valid_1's auc: 0.908715
# [10000]	training's auc: 0.939494	valid_1's auc: 0.910628
# [15000]	training's auc: 0.952147	valid_1's auc: 0.910816
# Early stopping, best iteration is:
# [12216]	training's auc: 0.945377	valid_1's auc: 0.910953
# Fold 14
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.924954	valid_1's auc: 0.893989
# [10000]	training's auc: 0.940347	valid_1's auc: 0.895635
# Early stopping, best iteration is:
# [10893]	training's auc: 0.942741	valid_1's auc: 0.895741
# CV score: 0.90066
# CPU times: user 5h 16min 26s, sys: 22.7 s, total: 5h 16min 49s
# Wall time: 1h 20min 14s

# %%
# Out:
# <bound method Booster.feature_importance of <lightgbm.basic.Booster object at 0x7fb1992a9e10>>
